# %%
# %reload_ext autoreload
# %autoreload 2

import torch
import torch.nn.functional as F

import refsr
import numpy as np

import images as I
import utils as U

import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

import os
import os.path as path

from PIL import Image

# %%
matplotlib.rc("savefig", dpi=100)
os.environ["CUDA_VISIBLE_DEVICES"]="0"
os.getcwd()
# Out:
# 'D:\\Josm\\Workspace\\ComputerVision\\GuidedTextureTransfer'

# %%
is_cuda=True
sr_model = refsr.get_default_sr_model(cuda=is_cuda)
vgg_model = refsr.get_default_vgg_model(cuda=is_cuda)
method = refsr.RefSR(sr_model, vgg_model)

# %%
# def match_image_and_segmentation(img, segmap):
#     assert img.dim() == 3
#     assert segmap.dim() == 3

#     _, H_img, W_img = img.size()
#     _, H_seg, W_seg = segmap.size()

#     H, W = min(H_img, H_seg), min(W_img, W_seg)

#     return img[:, :H, :W], segmap[:, :H, :W]


def showimg(img, title=None):
    if isinstance(img, torch.Tensor):
        img = I.to_pil_image(img)[0][0]
        
    if title is not None:
        print(title)
        
    plt.figure(figsize=(10, 10))
    plt.imshow(img)
    plt.show()

# %%
def load_data(imgpath, scale=1):
    dirname = path.dirname(imgpath)
    filename = path.basename(imgpath)
    basename, ext = path.splitext(filename)
    
    segpath = os.path.join(dirname, "prob", basename + "_seg.pth")
    
    img = I.load_image(imgpath, resize_scale=scale)
    
    segmap = torch.load(segpath)
    segmap = F.interpolate(segmap.unsqueeze(0), scale_factor=scale, mode="bicubic", align_corners=True).squeeze(0)
    
    assert img.dim() == 3
    assert segmap.dim() == 3
    assert img.shape[-2:] == segmap.shape[-2:]
    
    return img, segmap

def image_patches(h, w, s, img, *others):
    assert img.dim() == 3
    assert all([o.dim() == 3 for o in others])
    
    outputs = []
    
    patch = img[:, h:h+s, w:w+s]
    outputs.append(patch)
    
    _, ih, iw = img.size()
    for o in others:
        _, oh, ow = o.size()
        rh, rw = oh / ih, ow / iw
        patch = o[:, int(h*rh):int((h+s)*rh), int(w*rw):int((w+s)*rw)]
        outputs.append(patch)
        
    return tuple(outputs)

# %%
x_hr_orig, x_hr_seg_orig = load_data("samples/ctrl/input.png")
x_lr_orig, x_lr_seg_orig = load_data("samples/ctrl/input.png", scale=0.25)

x_hr, x_hr_seg, x_lr, x_lr_seg = image_patches(160, 650, 320, x_hr_orig, x_hr_seg_orig, x_lr_orig, x_lr_seg_orig)

r1, r1_seg = load_data("samples/ctrl/grass_left.png")
r2, r2_seg = load_data("samples/ctrl/grass_right.png")

showimg(x_hr_orig, "x_hr_orig")
showimg(x_lr_orig, "x_lr_orig")
showimg(x_hr, "x_hr")
showimg(x_lr, "x_hr")
showimg(r1, "r1")
showimg(r2, "r2")
# Out:
# x_hr_orig
# x_lr_orig
# x_hr
# x_hr
# r1
# r2

# %%
target_hr = x_hr
input_lr = x_lr
input_lr_seg = x_lr_seg

# %%
def loss(a, b):
    return (a.cuda() - b.cuda()).abs().mean()

def run_ref_seg(t, x, xseg, r, rseg):
    with torch.no_grad():
        if is_cuda:
            y=method.upscale_with_ref_with_seg(
                x=x.cuda(),
                x_seg=xseg.cuda(),
                refs=U.cuda_all(*r),
                refs_seg=U.cuda_all(*rseg),
            )
            torch.cuda.empty_cache()
        else:
            y=method.upscale_with_ref_with_seg(
                x=x,
                x_seg=xseg,
                refs=U.cuda_all(*r),
                refs_seg=U.cuda_all(*rseg),
            )
    
    print("--------------------------")
    print("Input")
    showimg(x)
    for i, rr in enumerate(r):
        print(f"Referece {i}")
        showimg(rr)
    print("Output")
    showimg(y)
    print("Target")
    showimg(t)
    print("Loss", loss(t, y))
    print("--------------------------")
    
    return y
def run_ref(t, x, r):
    with torch.no_grad():
        if is_cuda:
            y=method.upscale_with_ref(
                x=x.cuda(),
                refs=U.cuda_all(*r),
            )
            torch.cuda.empty_cache()
        else:
            y=method.upscale_with_ref(
                x=x,
                refs=U.cuda_all(*r),
            )
            
    print("--------------------------")
    print("Input")
    showimg(x)
    for i, rr in enumerate(r):
        print(f"Referece {i}")
        showimg(rr)
    print("Output")
    showimg(y)
    print("Target")
    showimg(t)
    print("Loss", loss(t, y))
    print("--------------------------")
    return y

# %%
run_ref_seg(target_hr, input_lr, input_lr_seg, [r1], [r1_seg])
print("Ok")
# Out:
# patches.size() torch.Size([48260, 256, 3, 3])
#
# Doing classidx 00
#
# Doing layer 1
# CondH=80, CondW=80
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([6708, 256, 3, 3])
# PatchSize torch.Size([6708, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=77, last_i_start=77, last_i_end=80
# last_j=77, last_j_start=77, last_j_end=80
# mask.mean() tensor(0.0458, device='cuda:0')
# mask.size() torch.Size([1, 1, 80, 80])
#
# Doing layer 2
# CondH=80, CondW=80
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([6708, 128, 6, 6])
# PatchSize torch.Size([6708, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=77, last_i_start=154, last_i_end=160
# last_j=77, last_j_start=154, last_j_end=160
# mask.mean() tensor(0.0452, device='cuda:0')
# mask.size() torch.Size([1, 1, 160, 160])
#
# Doing layer 3
# CondH=80, CondW=80
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([6708, 64, 12, 12])
# PatchSize torch.Size([6708, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 320, 320])
# counts.size torch.Size([320, 320])
# last_i=77, last_i_start=308, last_i_end=320
# last_j=77, last_j_start=308, last_j_end=320
# mask.mean() tensor(0.0442, device='cuda:0')
# mask.size() torch.Size([1, 1, 320, 320])
#
# Doing classidx 01
#
# Doing layer 1
# CondH=80, CondW=80
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([5060, 256, 3, 3])
# PatchSize torch.Size([5060, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=77, last_i_start=77, last_i_end=80
# last_j=77, last_j_start=77, last_j_end=80
# mask.mean() tensor(0.7119, device='cuda:0')
# mask.size() torch.Size([1, 1, 80, 80])
#
# Doing layer 2
# CondH=80, CondW=80
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([5060, 128, 6, 6])
# PatchSize torch.Size([5060, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=77, last_i_start=154, last_i_end=160
# last_j=77, last_j_start=154, last_j_end=160
# mask.mean() tensor(0.7118, device='cuda:0')
# mask.size() torch.Size([1, 1, 160, 160])
#
# Doing layer 3
# CondH=80, CondW=80
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([5060, 64, 12, 12])
# PatchSize torch.Size([5060, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 320, 320])
# counts.size torch.Size([320, 320])
# last_i=77, last_i_start=308, last_i_end=320
# last_j=77, last_j_start=308, last_j_end=320
# mask.mean() tensor(0.7142, device='cuda:0')
# mask.size() torch.Size([1, 1, 320, 320])
#
# Doing classidx 02
#
# Doing layer 1
# CondH=80, CondW=80
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([48260, 256, 3, 3])
# PatchSize torch.Size([48260, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=77, last_i_start=77, last_i_end=80
# last_j=77, last_j_start=77, last_j_end=80
# mask.mean() tensor(0.1505, device='cuda:0')
# mask.size() torch.Size([1, 1, 80, 80])
#
# Doing layer 2
# CondH=80, CondW=80
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([48260, 128, 6, 6])
# PatchSize torch.Size([48260, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=77, last_i_start=154, last_i_end=160
# last_j=77, last_j_start=154, last_j_end=160
# mask.mean() tensor(0.1534, device='cuda:0')
# mask.size() torch.Size([1, 1, 160, 160])
#
# Doing layer 3
# CondH=80, CondW=80
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([48260, 64, 12, 12])
# PatchSize torch.Size([48260, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 320, 320])
# counts.size torch.Size([320, 320])
# last_i=77, last_i_start=308, last_i_end=320
# last_j=77, last_j_start=308, last_j_end=320
# mask.mean() tensor(0.1524, device='cuda:0')
# mask.size() torch.Size([1, 1, 320, 320])
#
# Doing classidx 03
#
# Doing layer 1
# Class 3 for size 1 is skipped
#
# Doing layer 2
# Class 3 for size 2 is skipped
#
# Doing layer 3
# Class 3 for size 4 is skipped
#
# Doing classidx 04
#
# Doing layer 1
# Class 4 for size 1 is skipped
#
# Doing layer 2
# Class 4 for size 2 is skipped
#
# Doing layer 3
# Class 4 for size 4 is skipped
#
# Doing classidx 05
#
# Doing layer 1
# Class 5 for size 1 is skipped
#
# Doing layer 2
# Class 5 for size 2 is skipped
#
# Doing layer 3
# Class 5 for size 4 is skipped
#
# Doing classidx 06
#
# Doing layer 1
# CondH=80, CondW=80
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([11933, 256, 3, 3])
# PatchSize torch.Size([11933, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=77, last_i_start=77, last_i_end=80
# last_j=77, last_j_start=77, last_j_end=80
# mask.mean() tensor(0.0919, device='cuda:0')
# mask.size() torch.Size([1, 1, 80, 80])
#
# Doing layer 2
# CondH=80, CondW=80
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([11933, 128, 6, 6])
# PatchSize torch.Size([11933, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=77, last_i_start=154, last_i_end=160
# last_j=77, last_j_start=154, last_j_end=160
# mask.mean() tensor(0.0897, device='cuda:0')
# mask.size() torch.Size([1, 1, 160, 160])
#
# Doing layer 3
# CondH=80, CondW=80
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([11933, 64, 12, 12])
# PatchSize torch.Size([11933, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 320, 320])
# counts.size torch.Size([320, 320])
# last_i=77, last_i_start=308, last_i_end=320
# last_j=77, last_j_start=308, last_j_end=320
# mask.mean() tensor(0.0892, device='cuda:0')
# mask.size() torch.Size([1, 1, 320, 320])
#
# Doing classidx 07
#
# Doing layer 1
# Class 7 for size 1 is skipped
#
# Doing layer 2
# Class 7 for size 2 is skipped
#
# Doing layer 3
# Class 7 for size 4 is skipped
# --------------------------
# Input
# Referece 0
# Output
# Target
# Loss tensor(5.6404, device='cuda:0')
# --------------------------
# Ok

# %%
run_ref_seg(target_hr, input_lr, input_lr_seg, [r2], [r2_seg])
print("Ok")
# Out:
# patches.size() torch.Size([42672, 256, 3, 3])
#
# Doing classidx 00
#
# Doing layer 1
# CondH=80, CondW=80
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([42672, 256, 3, 3])
# PatchSize torch.Size([42672, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=77, last_i_start=77, last_i_end=80
# last_j=77, last_j_start=77, last_j_end=80
# mask.mean() tensor(0.0458, device='cuda:0')
# mask.size() torch.Size([1, 1, 80, 80])
#
# Doing layer 2
# CondH=80, CondW=80
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([42672, 128, 6, 6])
# PatchSize torch.Size([42672, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=77, last_i_start=154, last_i_end=160
# last_j=77, last_j_start=154, last_j_end=160
# mask.mean() tensor(0.0452, device='cuda:0')
# mask.size() torch.Size([1, 1, 160, 160])
#
# Doing layer 3
# CondH=80, CondW=80
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([42672, 64, 12, 12])
# PatchSize torch.Size([42672, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 320, 320])
# counts.size torch.Size([320, 320])
# last_i=77, last_i_start=308, last_i_end=320
# last_j=77, last_j_start=308, last_j_end=320
# mask.mean() tensor(0.0442, device='cuda:0')
# mask.size() torch.Size([1, 1, 320, 320])
#
# Doing classidx 01
#
# Doing layer 1
# CondH=80, CondW=80
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([42672, 256, 3, 3])
# PatchSize torch.Size([42672, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=77, last_i_start=77, last_i_end=80
# last_j=77, last_j_start=77, last_j_end=80
# mask.mean() tensor(0.7119, device='cuda:0')
# mask.size() torch.Size([1, 1, 80, 80])
#
# Doing layer 2
# CondH=80, CondW=80
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([42672, 128, 6, 6])
# PatchSize torch.Size([42672, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=77, last_i_start=154, last_i_end=160
# last_j=77, last_j_start=154, last_j_end=160
# mask.mean() tensor(0.7118, device='cuda:0')
# mask.size() torch.Size([1, 1, 160, 160])
#
# Doing layer 3
# CondH=80, CondW=80
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([42672, 64, 12, 12])
# PatchSize torch.Size([42672, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 320, 320])
# counts.size torch.Size([320, 320])
# last_i=77, last_i_start=308, last_i_end=320
# last_j=77, last_j_start=308, last_j_end=320
# mask.mean() tensor(0.7142, device='cuda:0')
# mask.size() torch.Size([1, 1, 320, 320])
#
# Doing classidx 02
#
# Doing layer 1
# CondH=80, CondW=80
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([11379, 256, 3, 3])
# PatchSize torch.Size([11379, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=77, last_i_start=77, last_i_end=80
# last_j=77, last_j_start=77, last_j_end=80
# mask.mean() tensor(0.1505, device='cuda:0')
# mask.size() torch.Size([1, 1, 80, 80])
#
# Doing layer 2
# CondH=80, CondW=80
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([11379, 128, 6, 6])
# PatchSize torch.Size([11379, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=77, last_i_start=154, last_i_end=160
# last_j=77, last_j_start=154, last_j_end=160
# mask.mean() tensor(0.1534, device='cuda:0')
# mask.size() torch.Size([1, 1, 160, 160])
#
# Doing layer 3
# CondH=80, CondW=80
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([11379, 64, 12, 12])
# PatchSize torch.Size([11379, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 320, 320])
# counts.size torch.Size([320, 320])
# last_i=77, last_i_start=308, last_i_end=320
# last_j=77, last_j_start=308, last_j_end=320
# mask.mean() tensor(0.1524, device='cuda:0')
# mask.size() torch.Size([1, 1, 320, 320])
#
# Doing classidx 03
#
# Doing layer 1
# Class 3 for size 1 is skipped
#
# Doing layer 2
# Class 3 for size 2 is skipped
#
# Doing layer 3
# Class 3 for size 4 is skipped
#
# Doing classidx 04
#
# Doing layer 1
# Class 4 for size 1 is skipped
#
# Doing layer 2
# Class 4 for size 2 is skipped
#
# Doing layer 3
# Class 4 for size 4 is skipped
#
# Doing classidx 05
#
# Doing layer 1
# Class 5 for size 1 is skipped
#
# Doing layer 2
# Class 5 for size 2 is skipped
#
# Doing layer 3
# Class 5 for size 4 is skipped
#
# Doing classidx 06
#
# Doing layer 1
# CondH=80, CondW=80
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([42672, 256, 3, 3])
# PatchSize torch.Size([42672, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=77, last_i_start=77, last_i_end=80
# last_j=77, last_j_start=77, last_j_end=80
# mask.mean() tensor(0.0919, device='cuda:0')
# mask.size() torch.Size([1, 1, 80, 80])
#
# Doing layer 2
# CondH=80, CondW=80
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([42672, 128, 6, 6])
# PatchSize torch.Size([42672, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=77, last_i_start=154, last_i_end=160
# last_j=77, last_j_start=154, last_j_end=160
# mask.mean() tensor(0.0897, device='cuda:0')
# mask.size() torch.Size([1, 1, 160, 160])
#
# Doing layer 3
# CondH=80, CondW=80
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([42672, 64, 12, 12])
# PatchSize torch.Size([42672, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 320, 320])
# counts.size torch.Size([320, 320])
# last_i=77, last_i_start=308, last_i_end=320
# last_j=77, last_j_start=308, last_j_end=320
# mask.mean() tensor(0.0892, device='cuda:0')
# mask.size() torch.Size([1, 1, 320, 320])
#
# Doing classidx 07
#
# Doing layer 1
# Class 7 for size 1 is skipped
#
# Doing layer 2
# Class 7 for size 2 is skipped
#
# Doing layer 3
# Class 7 for size 4 is skipped
# --------------------------
# Input
# Referece 0
# Output
# Target
# Loss tensor(5.6147, device='cuda:0')
# --------------------------
# Ok

# %%
run_ref_seg(target_hr, input_lr, input_lr_seg, [r1, r2], [r1_seg, r2_seg])
print("Ok")
# Out:
# patches.size() torch.Size([90932, 256, 3, 3])
#
# Doing classidx 00
#
# Doing layer 1
# CondH=80, CondW=80
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([6708, 256, 3, 3])
# PatchSize torch.Size([6708, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=77, last_i_start=77, last_i_end=80
# last_j=77, last_j_start=77, last_j_end=80
# mask.mean() tensor(0.0458, device='cuda:0')
# mask.size() torch.Size([1, 1, 80, 80])
#
# Doing layer 2
# CondH=80, CondW=80
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# Subset torch.Size([6708, 128, 6, 6])
# PatchSize torch.Size([6708, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=77, last_i_start=154, last_i_end=160
# last_j=77, last_j_start=154, last_j_end=160
# mask.mean() tensor(0.0452, device='cuda:0')
# mask.size() torch.Size([1, 1, 160, 160])
#
# Doing layer 3
# CondH=80, CondW=80
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=78, Addr_W=78
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-11-728c3abd9d08> in <module>
# ----> 1 run_ref_seg(target_hr, input_lr, input_lr_seg, [r1, r2], [r1_seg, r2_seg])
#       2 print("Ok")
#
# <ipython-input-8-ec5c2d0da28e> in run_ref_seg(t, x, xseg, r, rseg)
#       9                 x_seg=xseg.cuda(),
#      10                 refs=U.cuda_all(*r),
# ---> 11                 refs_seg=U.cuda_all(*rseg),
#      12             )
#      13             torch.cuda.empty_cache()
#
# D:\Josm\Workspace\ComputerVision\GuidedTextureTransfer\refsr.py in upscale_with_ref_with_seg(self, x, x_seg, refs, refs_seg)
#     255                     patch_size=self.patch_size,
#     256                     stride=self.stride,
# --> 257                     patch_postprocess=filter_patches)[0]
#     258
#     259                 if feature.dim() == 3:
#
# D:\Josm\Workspace\ComputerVision\GuidedTextureTransfer\swapper.py in stitch(condition_size, ratio, addr, refs, patch_size, stride, patch_postprocess)
#     118     assert patch_postprocess is None or callable(patch_postprocess)
#     119
# --> 120     patches = P.to_patches(refs, patch_size=(PH * RH, PW * RW), stride=(SH * RH, SW * RW))
#     121     patches = patches.cpu() if device < 0 else patches.to(device=device)
#     122     if patch_postprocess is not None:
#
# D:\Josm\Workspace\ComputerVision\GuidedTextureTransfer\patches.py in to_patches(x, patch_size, dilation, padding, stride)
#      16                 batches = p
#      17             else:
# ---> 18                 batches = torch.cat([batches, p], dim=0)
#      19             del t, p
#      20         return batches
#
# RuntimeError: CUDA out of memory. Tried to allocate 3.12 GiB (GPU 0; 8.00 GiB total capacity; 3.74 GiB already allocated; 1.28 GiB free; 1.23 GiB cached)
