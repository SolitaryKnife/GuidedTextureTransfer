# %%
# %reload_ext autoreload
# %autoreload 2

import torch
import torch.nn.functional as F

import refsr
import numpy as np

import images as I
import utils as U

import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

import os

from PIL import Image

# %%
os.getcwd()
# Out:
# 'D:\\Josm\\Workspace\\ComputerVision\\SRNTT\\ctrltt'

# %%
is_cuda=True
sr_model = refsr.get_default_sr_model(cuda=is_cuda)
vgg_model = refsr.get_default_vgg_model(cuda=is_cuda)
method = refsr.RefSR(sr_model, vgg_model)

# %%
def match_image_and_segmentation(img, segmap):
    assert img.dim() == 3
    assert segmap.dim() == 3

    _, H_img, W_img = img.size()
    _, H_seg, W_seg = segmap.size()

    H, W = min(H_img, H_seg), min(W_img, W_seg)

    return img[:, :H, :W], segmap[:, :H, :W]

# %%
size=160
dx, dy = 160, 160

x_hr=I.load_image("samples/img_001_SRF_8_HR.png")
x_hr_seg=I.torch.load("samples/img_001_SRF_8_HR_bic.pth")
x_hr, x_hr_seg = match_image_and_segmentation(x_hr, x_hr_seg)

x_hr = x_hr[:, dx:dx+size, dy:dy+size]
x_hr_seg = x_hr_seg[:, dx:dx+size, dy:dy+size]

x=I.load_image("samples/img_001_SRF_8_HR.png", resize_scale=0.25)[:, dx//4:(dx+size)//4, dy//4:(dy+size)//4]
x_seg = method.downscale(x_hr_seg.unsqueeze(0)).squeeze(0)

r1=I.load_image("samples/img_047_SRF_8_HR.png")
r1_seg=I.torch.load("samples/img_047_SRF_8_HR_bic.pth")
r1, r1_seg = match_image_and_segmentation(r1, r1_seg)

r2=I.load_image("samples/img_068_SRF_8_HR.png")
r2_seg=I.torch.load("samples/img_068_SRF_8_HR_bic.pth")
r2, r2_seg = match_image_and_segmentation(r2, r2_seg)

# r3=I.load_image("samples/000_3.png")[0]
# r4=I.load_image("samples/000_4.png")[0]

# %%
I.to_pil_image(x_hr)[0][0]
# Out:
# <PIL.Image.Image image mode=RGB size=160x160 at 0x27D8EAD54A8>

# %%
# sr_model.cpu()
# vgg_model.cpu()
with torch.no_grad():
    if is_cuda:
        y=method.upscale_with_ref_with_seg(
            x=x.cuda(),
            x_seg=x_seg.cuda(),
            refs=U.cuda_all(r1, r2),
            refs_seg=U.cuda_all(r1_seg, r2_seg),
        )
    else:
        y=method.upscale_with_ref_with_seg(
            x=x,
            x_seg=x_seg,
            refs=(r1, r2),
            refs_seg=(r1_seg, r2_seg),
        )
I.to_pil_image(y)[0][0]
# Out:
# patches.size() torch.Size([96520, 256, 3, 3])
#
# Doing classidx 00
#
# Doint layer 1
# CondH=40, CondW=40
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([2653, 256, 3, 3])
# PatchSize torch.Size([2653, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 40, 40])
# counts.size torch.Size([40, 40])
# last_i=37, last_i_start=37, last_i_end=40
# last_j=37, last_j_start=37, last_j_end=40
# torch.Size([1, 256, 40, 40]) torch.Size([1, 40, 40])
#
# Doint layer 2
# CondH=40, CondW=40
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([2653, 128, 6, 6])
# PatchSize torch.Size([2653, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=37, last_i_start=74, last_i_end=80
# last_j=37, last_j_start=74, last_j_end=80
# torch.Size([1, 128, 80, 80]) torch.Size([1, 80, 80])
#
# Doint layer 3
# CondH=40, CondW=40
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([2653, 64, 12, 12])
# PatchSize torch.Size([2653, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=37, last_i_start=148, last_i_end=160
# last_j=37, last_j_start=148, last_j_end=160
# torch.Size([1, 64, 160, 160]) torch.Size([1, 160, 160])
#
# Doing classidx 01
#
# Doint layer 1
# CondH=40, CondW=40
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([18257, 256, 3, 3])
# PatchSize torch.Size([18257, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 40, 40])
# counts.size torch.Size([40, 40])
# last_i=37, last_i_start=37, last_i_end=40
# last_j=37, last_j_start=37, last_j_end=40
# torch.Size([1, 256, 40, 40]) torch.Size([1, 40, 40])
#
# Doint layer 2
# CondH=40, CondW=40
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([18257, 128, 6, 6])
# PatchSize torch.Size([18257, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=37, last_i_start=74, last_i_end=80
# last_j=37, last_j_start=74, last_j_end=80
# torch.Size([1, 128, 80, 80]) torch.Size([1, 80, 80])
#
# Doint layer 3
# CondH=40, CondW=40
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([18257, 64, 12, 12])
# PatchSize torch.Size([18257, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=37, last_i_start=148, last_i_end=160
# last_j=37, last_j_start=148, last_j_end=160
# torch.Size([1, 64, 160, 160]) torch.Size([1, 160, 160])
#
# Doing classidx 02
#
# Doint layer 1
# CondH=40, CondW=40
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([6117, 256, 3, 3])
# PatchSize torch.Size([6117, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 40, 40])
# counts.size torch.Size([40, 40])
# last_i=37, last_i_start=37, last_i_end=40
# last_j=37, last_j_start=37, last_j_end=40
# torch.Size([1, 256, 40, 40]) torch.Size([1, 40, 40])
#
# Doint layer 2
# CondH=40, CondW=40
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([6117, 128, 6, 6])
# PatchSize torch.Size([6117, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=37, last_i_start=74, last_i_end=80
# last_j=37, last_j_start=74, last_j_end=80
# torch.Size([1, 128, 80, 80]) torch.Size([1, 80, 80])
#
# Doint layer 3
# CondH=40, CondW=40
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([6117, 64, 12, 12])
# PatchSize torch.Size([6117, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=37, last_i_start=148, last_i_end=160
# last_j=37, last_j_start=148, last_j_end=160
# torch.Size([1, 64, 160, 160]) torch.Size([1, 160, 160])
#
# Doing classidx 03
#
# Doint layer 1
# CondH=40, CondW=40
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([12831, 256, 3, 3])
# PatchSize torch.Size([12831, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 40, 40])
# counts.size torch.Size([40, 40])
# last_i=37, last_i_start=37, last_i_end=40
# last_j=37, last_j_start=37, last_j_end=40
# torch.Size([1, 256, 40, 40]) torch.Size([1, 40, 40])
#
# Doint layer 2
# CondH=40, CondW=40
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([12831, 128, 6, 6])
# PatchSize torch.Size([12831, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=37, last_i_start=74, last_i_end=80
# last_j=37, last_j_start=74, last_j_end=80
# torch.Size([1, 128, 80, 80]) torch.Size([1, 80, 80])
#
# Doint layer 3
# CondH=40, CondW=40
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([12831, 64, 12, 12])
# PatchSize torch.Size([12831, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=37, last_i_start=148, last_i_end=160
# last_j=37, last_j_start=148, last_j_end=160
# torch.Size([1, 64, 160, 160]) torch.Size([1, 160, 160])
#
# Doing classidx 04
#
# Doint layer 1
# CondH=40, CondW=40
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([95, 256, 3, 3])
# PatchSize torch.Size([95, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 40, 40])
# counts.size torch.Size([40, 40])
# last_i=37, last_i_start=37, last_i_end=40
# last_j=37, last_j_start=37, last_j_end=40
# torch.Size([1, 256, 40, 40]) torch.Size([1, 40, 40])
#
# Doint layer 2
# CondH=40, CondW=40
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([95, 128, 6, 6])
# PatchSize torch.Size([95, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=37, last_i_start=74, last_i_end=80
# last_j=37, last_j_start=74, last_j_end=80
# torch.Size([1, 128, 80, 80]) torch.Size([1, 80, 80])
#
# Doint layer 3
# CondH=40, CondW=40
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([95, 64, 12, 12])
# PatchSize torch.Size([95, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=37, last_i_start=148, last_i_end=160
# last_j=37, last_j_start=148, last_j_end=160
# torch.Size([1, 64, 160, 160]) torch.Size([1, 160, 160])
#
# Doing classidx 05
#
# Doint layer 1
# CondH=40, CondW=40
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([23653, 256, 3, 3])
# PatchSize torch.Size([23653, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 40, 40])
# counts.size torch.Size([40, 40])
# last_i=37, last_i_start=37, last_i_end=40
# last_j=37, last_j_start=37, last_j_end=40
# torch.Size([1, 256, 40, 40]) torch.Size([1, 40, 40])
#
# Doint layer 2
# CondH=40, CondW=40
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([23653, 128, 6, 6])
# PatchSize torch.Size([23653, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=37, last_i_start=74, last_i_end=80
# last_j=37, last_j_start=74, last_j_end=80
# torch.Size([1, 128, 80, 80]) torch.Size([1, 80, 80])
#
# Doint layer 3
# CondH=40, CondW=40
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([23653, 64, 12, 12])
# PatchSize torch.Size([23653, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=37, last_i_start=148, last_i_end=160
# last_j=37, last_j_start=148, last_j_end=160
# torch.Size([1, 64, 160, 160]) torch.Size([1, 160, 160])
#
# Doing classidx 06
#
# Doint layer 1
# CondH=40, CondW=40
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([32914, 256, 3, 3])
# PatchSize torch.Size([32914, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 40, 40])
# counts.size torch.Size([40, 40])
# last_i=37, last_i_start=37, last_i_end=40
# last_j=37, last_j_start=37, last_j_end=40
# torch.Size([1, 256, 40, 40]) torch.Size([1, 40, 40])
#
# Doint layer 2
# CondH=40, CondW=40
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([32914, 128, 6, 6])
# PatchSize torch.Size([32914, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=37, last_i_start=74, last_i_end=80
# last_j=37, last_j_start=74, last_j_end=80
# torch.Size([1, 128, 80, 80]) torch.Size([1, 80, 80])
#
# Doint layer 3
# CondH=40, CondW=40
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([32914, 64, 12, 12])
# PatchSize torch.Size([32914, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=37, last_i_start=148, last_i_end=160
# last_j=37, last_j_start=148, last_j_end=160
# torch.Size([1, 64, 160, 160]) torch.Size([1, 160, 160])
#
# Doing classidx 07
#
# Doint layer 1
# CondH=40, CondW=40
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([96520, 256, 3, 3])
# PatchSize torch.Size([96520, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 40, 40])
# counts.size torch.Size([40, 40])
# last_i=37, last_i_start=37, last_i_end=40
# last_j=37, last_j_start=37, last_j_end=40
# torch.Size([1, 256, 40, 40]) torch.Size([1, 40, 40])
#
# Doint layer 2
# CondH=40, CondW=40
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([96520, 128, 6, 6])
# PatchSize torch.Size([96520, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=37, last_i_start=74, last_i_end=80
# last_j=37, last_j_start=74, last_j_end=80
# torch.Size([1, 128, 80, 80]) torch.Size([1, 80, 80])
#
# Doint layer 3
# CondH=40, CondW=40
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# Subset torch.Size([96520, 64, 12, 12])
# PatchSize torch.Size([96520, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=37, last_i_start=148, last_i_end=160
# last_j=37, last_j_start=148, last_j_end=160
# torch.Size([1, 64, 160, 160]) torch.Size([1, 160, 160])
# <PIL.Image.Image image mode=RGB size=160x160 at 0x27DF1EA77F0>

# %%
with torch.no_grad():
    if is_cuda:
        y2=method.upscale_with_ref(
            x=x.cuda(),
            refs=U.cuda_all(r1, r2)
        )
    else:
        y2=method.upscale_with_ref(
            x=x,
            refs=(r1, r2)
        )
I.to_pil_image(y2)[0][0]
# Out:
# CondH=40, CondW=40
# RH=1, RW=1
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# PatchSize torch.Size([96520, 256, 3, 3])
# NewPatch_H=3, NewPatch_W=3
# outputs.size torch.Size([256, 40, 40])
# counts.size torch.Size([40, 40])
# last_i=37, last_i_start=37, last_i_end=40
# last_j=37, last_j_start=37, last_j_end=40
# CondH=40, CondW=40
# RH=2, RW=2
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# PatchSize torch.Size([96520, 128, 6, 6])
# NewPatch_H=6, NewPatch_W=6
# outputs.size torch.Size([128, 80, 80])
# counts.size torch.Size([80, 80])
# last_i=37, last_i_start=74, last_i_end=80
# last_j=37, last_j_start=74, last_j_end=80
# CondH=40, CondW=40
# RH=4, RW=4
# Patch_H=3, Patch_W=3
# Stride_H=1, Stride_W=1
# Addr_H=38, Addr_W=38
# PatchSize torch.Size([96520, 64, 12, 12])
# NewPatch_H=12, NewPatch_W=12
# outputs.size torch.Size([64, 160, 160])
# counts.size torch.Size([160, 160])
# last_i=37, last_i_start=148, last_i_end=160
# last_j=37, last_j_start=148, last_j_end=160
# <PIL.Image.Image image mode=RGB size=160x160 at 0x27DF1EA76A0>

# %%
import patches as P

print(P.to_patches(torch.ones(10, 3, 20, 20)).size())
print(P.to_patches(torch.ones(10, 11, 20, 20)).size())
# Out:
# torch.Size([3240, 3, 3, 3])
# torch.Size([3240, 11, 3, 3])

# %%
I.to_pil_image(y2)[0][0]
# Out:
# <PIL.Image.Image image mode=RGB size=160x160 at 0x27D94772710>

# %%
img = Image.open("samples/000_0.png")
W, H = img.size
size =  160
xH, xW = H % size, W % size

counts = 0
for i in range(0, H - xH, size):
    for j in range(0, W - xW, size):
        top = i
        left = j
        bottom = i + size
        right = j + size
        im1 = img.crop((left, top, right, bottom))
        
        plt.imshow(im1)
        plt.show()
        
        print(left, top, right, bottom)
        counts += 1
        
print(counts)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-5e57e6048df9> in <module>
# ----> 1 img = Image.open("samples/000_0.png")
#       2 W, H = img.size
#       3 size =  160
#       4 xH, xW = H % size, W % size
#       5
#
# ~\Anaconda3\envs\pytorch\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2764
#    2765     if filename:
# -> 2766         fp = builtins.open(filename, "rb")
#    2767         exclusive_fp = True
#    2768
#
# FileNotFoundError: [Errno 2] No such file or directory: 'samples/000_0.png'

# %%
img.size
