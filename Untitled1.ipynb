# %%
import utils as U
import dataset.cufed5 as c5

from tqdm import tqdm
from PIL import Image

import torch
import torch.nn.functional as F

import torchvision.transforms as T
import torchvision.transforms.functional as TF

import images as I

import refsr

import metrics as M
import patches as P

import os


is_cuda=True
refsr_model = refsr.get_default_sr_model(cuda=is_cuda)
vgg_model = refsr.get_default_vgg_model(cuda=is_cuda)
method = refsr.RefSR(refsr_model, refsr_model, vgg_model)

model_names = ["bicub", "edsr", "srgan"]
sim_levels = 5

ssim_data = {model_name: [[] for _ in range(sim_levels)] for model_name in model_names}
psnr_data = {model_name: [[] for _ in range(sim_levels)] for model_name in model_names}

base_ssim_data = {model_name: [[] for _ in range(sim_levels)] for model_name in model_names}
base_psnr_data = {model_name: [[] for _ in range(sim_levels)] for model_name in model_names}

transform = T.Compose([
    T.ToTensor(),
    T.Lambda(lambda x: x.cuda().unsqueeze(0) * 255)
])

for sim_level in range(1,6):
    print("SimLevel", sim_level)
    
    for i in tqdm(range(126)):
        hrlist = U.data.ImageDataset(f"data/test/proc/cufed5/{i:03}/hr/*.png", transform)
        lrlist = U.data.ImageDataset(f"data/test/proc/cufed5/{i:03}/lr/*.png", transform)
        reflist = list(U.data.ImageDataset(f"data/test/proc/cufed5/{i:03}/s{sim_level}/*.png", transform))
        
        models = {
            "bicub": U.data.ImageDataset(f"data/test/proc/cufed5/{i:03}/__bicub/*.png", transform),
            "edsr": U.data.ImageDataset(f"data/test/proc/cufed5/{i:03}/__edsr/*.png", transform),
            "srgan": U.data.ImageDataset(f"data/test/proc/cufed5/{i:03}/__srgan/*.png", transform),
        }

        for model_name in models:
            print("model_name", model_name)
            model_outputs = models[model_name]
            
            
            print("base_model")
            for idx in range(len(model_outputs)):
                x = model_outputs[idx]
                y = hrlist[idx]

                x, y = x / 255, y / 255
                base_psnr = M.pytorch_psnr(x, y).item()
                base_ssim = M.pytorch_ssim(x, y).item()

                base_psnr_data[model_name][sim_level - 1].append(base_psnr)
                base_ssim_data[model_name][sim_level - 1].append(base_ssim)
                

            for idx in range(len(model_outputs)):
                
                print(f"improved_model #{idx+1}/{len(model_outputs)}")
                x = model_outputs[idx]
                y = method.upscale_with_ref(
                    x=x,
                    refs=reflist)
                
                fpath = f"data/test/proc/cufed5/{i:03}/__{model_name}_ours/big/{idx:03}.png"
                try:
                    os.makedirs(os.path.dirname(fpath))
                except:
                    pass
                TF.to_pil_image(y.squeeze(0).cpu() / 255).save(fpath)

                y_small = F.interpolate(y, scale_factor=0.25, mode="bicubic", align_corners=True)
                y2 = hrlist[idx]
                
                fpath = f"data/test/proc/cufed5/{i:03}/__{model_name}_ours/small/{idx:03}.png"
                try:
                    os.makedirs(os.path.dirname(fpath))
                except:
                    pass
                TF.to_pil_image(y_small.squeeze(0).cpu() / 255).save(fpath)

                y_small, y2 = y_small / 255, y2 / 255
                psnr = M.pytorch_psnr(y_small, y2).item()
                ssim = M.pytorch_ssim(y_small, y2).item()
                
                base_psnr_data[model_name][sim_level - 1].append(psnr)
                base_ssim_data[model_name][sim_level - 1].append(ssim)

import json
with open('ssim_data.json', 'w') as f:
    json.dump(ssim_data, f)
with open('psnr_data.json', 'w') as f:
    json.dump(ssim_data, f)
with open('base_ssim_data.json', 'w') as f:
    json.dump(ssim_data, f)
with open('base_psnr_data.json', 'w') as f:
    json.dump(ssim_data, f)7
# Out:
# SimLevel 1
#   0%|                                                                                                                                                                | 0/126 [00:00<?, ?it/s]
# model_name bicub
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
# model_name edsr
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
# model_name srgan
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
#   1%|█▏                                                                                                                                                  | 1/126 [04:57<10:20:42, 297.94s/it]
# model_name bicub
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
# model_name edsr
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
# model_name srgan
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
#   2%|██▎                                                                                                                                                 | 2/126 [09:54<10:15:10, 297.67s/it]
# model_name bicub
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
# model_name edsr
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
# model_name srgan
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
#   2%|███▌                                                                                                                                                | 3/126 [14:41<10:03:35, 294.44s/it]
# model_name bicub
# base_model
# improved_model #1/12
# improved_model #2/12
# improved_model #3/12
# improved_model #4/12
# improved_model #5/12
# improved_model #6/12
# improved_model #7/12
# improved_model #8/12
# improved_model #9/12
# improved_model #10/12
# improved_model #11/12
# improved_model #12/12
# model_name edsr
# base_model
# improved_model #1/12
# improved_model #2/12
# improved_model #3/12
# improved_model #4/12
# improved_model #5/12
# improved_model #6/12
# improved_model #7/12
# improved_model #8/12
# improved_model #9/12
# improved_model #10/12
# improved_model #11/12
# improved_model #12/12
# model_name srgan
# base_model
# improved_model #1/12
# improved_model #2/12
# improved_model #3/12
# improved_model #4/12
# improved_model #5/12
# improved_model #6/12
# improved_model #7/12
# improved_model #8/12
# improved_model #9/12
# improved_model #10/12
# improved_model #11/12
# improved_model #12/12
#   3%|████▋                                                                                                                                               | 4/126 [22:07<11:30:52, 339.77s/it]
# model_name bicub
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
# model_name edsr
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
# model_name srgan
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
#   4%|█████▊                                                                                                                                              | 5/126 [26:57<10:55:26, 325.01s/it]
# model_name bicub
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
# model_name edsr
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
# model_name srgan
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
#   5%|███████                                                                                                                                             | 6/126 [31:56<10:34:00, 317.00s/it]
# model_name bicub
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
# model_name edsr
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
# model_name srgan
# base_model
# improved_model #1/8
# improved_model #2/8
# improved_model #3/8
# improved_model #4/8
# improved_model #5/8
# improved_model #6/8
# improved_model #7/8
# improved_model #8/8
#   6%|████████▏                                                                                                                                           | 7/126 [36:55<10:18:16, 311.74s/it]
# model_name bicub
# base_model
# improved_model #1/12
# improved_model #2/12
# improved_model #3/12
# improved_model #4/12
# improved_model #5/12
# improved_model #6/12
# improved_model #7/12
# improved_model #8/12
# improved_model #9/12
# improved_model #10/12
# improved_model #11/12
# improved_model #12/12
# model_name edsr
# base_model
# improved_model #1/12
# improved_model #2/12
# improved_model #3/12
# improved_model #4/12
# improved_model #5/12
# improved_model #6/12
# improved_model #7/12
# improved_model #8/12
# improved_model #9/12
# improved_model #10/12
# improved_model #11/12
# improved_model #12/12
# model_name srgan
# base_model
# improved_model #1/12
# improved_model #2/12
# improved_model #3/12
# improved_model #4/12
# improved_model #5/12
# improved_model #6/12
# improved_model #7/12
# improved_model #8/12
# improved_model #9/12
# improved_model #10/12
# improved_model #11/12
# improved_model #12/12
#   6%|█████████▍                                                                                                                                          | 8/126 [44:28<11:36:01, 353.91s/it]
# model_name bicub
# base_model
# improved_model #1/8
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-1-eec7477a26fd> in <module>
#      78                 y = method.upscale_with_ref(
#      79                     x=x,
# ---> 80                     refs=reflist)
#      81
#      82                 fpath = f"data/test/proc/cufed5/{i:03}/__{model_name}_ours/big/{idx:03}.png"
#
# D:\Josm\Workspace\ComputerVision\GuidedTextureTransfer\refsr.py in upscale_with_ref(self, x, refs)
#     102
#     103         x = self._assert_valid_image(x)
# --> 104         refs = [self._assert_valid_image(ref) for ref in refs]
#     105
#     106         x_sr = self.upscale(x)
#
# D:\Josm\Workspace\ComputerVision\GuidedTextureTransfer\refsr.py in <listcomp>(.0)
#     102
#     103         x = self._assert_valid_image(x)
# --> 104         refs = [self._assert_valid_image(ref) for ref in refs]
#     105
#     106         x_sr = self.upscale(x)
#
# D:\Josm\Workspace\ComputerVision\GuidedTextureTransfer\refsr.py in _assert_valid_image(self, x)
#      63         assert x.dim() == 4
#      64         assert x.size(1) == 3, "Image must be an RGB tensor"
# ---> 65         assert x.mean() >= 1 and x.min() >= 0, "Image must have values in range [0,255]"
#      66         return x
#      67
#
# AssertionError: Image must have values in range [0,255]
